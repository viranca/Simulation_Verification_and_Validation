# %%
import numpy as np
import pandas as pd

from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

from matplotlib import pyplot as plt
from pandas import read_csv
from pandas import DataFrame
from pandas import concat

# %%
ml = pd.read_csv('missesleading.csv')
mt = pd.read_csv('missestrailing.csv')

# %%
ml = ml.sort_values(['x-coordinate'], ascending=[1])
ml.plot(x='x-coordinate', y='U.U2')

# %%
ml = ml.sort_values(['x-coordinate'], ascending=[1])
ml.plot(x='x-coordinate', y='U.U3')

# %%
ml = ml.sort_values(['x-coordinate'], ascending=[1])
ml.plot(x='x-coordinate', y='U.Magnitude')

# %%
ml.loc[ml['U.U1'].idxmax()]
# Out:
# Node Label       208.00000
# x-coordinate    1042.19995
# y-coordinate       0.00000
# z-coordinate     112.50000
# missesavg        792.00000
# U.U1             682.00000
# U.U2            -502.47100
# U.U3             354.00000
# U.Magnitude      502.47100
# Name: 79, dtype: float64

# %%
ml.loc[ml['U.U2'].idxmax()]
# Out:
# Node Label         1.000
# x-coordinate    2771.000
# y-coordinate       0.000
# z-coordinate     112.500
# missesavg          1.914
# U.U1            -135.000
# U.U2            -328.734
# U.U3             367.000
# U.Magnitude      328.737
# Name: 112, dtype: float64

# %%
ml.loc[ml['U.U3'].idxmax()]
# Out:
# Node Label      241.000000
# x-coordinate    227.100006
# y-coordinate      0.000000
# z-coordinate    112.500000
# missesavg       788.000000
# U.U1           -587.000000
# U.U2           -410.612000
# U.U3            961.000000
# U.Magnitude     410.612000
# Name: 30, dtype: float64

# %%
ml.loc[ml['U.Magnitude'].idxmax()]
# Out:
# Node Label      7.000000e+00
# x-coordinate    1.281000e+03
# y-coordinate    0.000000e+00
# z-coordinate    1.125000e+02
# missesavg       1.434000e+03
# U.U1            4.980000e+02
# U.U2           -5.105250e+02
# U.U3           -9.700000e-31
# U.Magnitude     5.105250e+02
# Name: 27, dtype: float64

# %%
mt = mt.sort_values(['x-coordinate'], ascending=[1])
mt.plot(x='x-coordinate', y='U.U2')

# %%
mt = mt.sort_values(['x-coordinate'], ascending=[1])
mt.plot(x='x-coordinate', y='U.U3')

# %%
mt = mt.sort_values(['x-coordinate'], ascending=[1])
mt.plot(x='x-coordinate', y='U.Magnitude')

# %%
mt.loc[ml['U.U1'].idxmax()]
# Out:
# Node Label      697.000000
# x-coordinate    992.799988
# y-coordinate      0.000000
# z-coordinate   -434.500000
# missesavg       223.333333
# U.U1           -114.000000
# U.U2            198.059000
# U.U3            388.000000
# U.Magnitude     198.059000
# Name: 79, dtype: float64

# %%
mt.loc[ml['U.U2'].idxmax()]
# Out:
# Node Label      713.000000
# x-coordinate    597.599976
# y-coordinate      0.000000
# z-coordinate   -434.500000
# missesavg       293.000000
# U.U1           -515.000000
# U.U2            201.942000
# U.U3            498.000000
# U.Magnitude     201.942000
# Name: 112, dtype: float64

# %%
mt.loc[ml['U.U3'].idxmax()]
# Out:
# Node Label      726.000000
# x-coordinate    276.500000
# y-coordinate      0.000000
# z-coordinate   -434.500000
# missesavg       185.666667
# U.U1           -302.000000
# U.U2            206.313000
# U.U3            175.000000
# U.Magnitude     206.313000
# Name: 30, dtype: float64

# %%
mt.loc[ml['U.Magnitude'].idxmax()]
# Out:
# Node Label      723.000000
# x-coordinate    350.600006
# y-coordinate      0.000000
# z-coordinate   -434.500000
# missesavg       195.666667
# U.U1           -304.000000
# U.U2            205.232000
# U.U3            254.000000
# U.Magnitude     205.232000
# Name: 27, dtype: float64
